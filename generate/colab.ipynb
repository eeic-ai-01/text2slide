# %%
from google.colab import drive
drive.mount('/content/drive',  force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/AI_Experiment/generate_slide
# Out:
# /content/drive/My Drive/AI_Experiment/generate_slide

# %%
ls
# Out:
# fastText/  prediction.py  slide_1.pptx  slide_3.pptx  Untitled0.ipynb
# out.md     script.txt     slide_2.pptx  templates/    wikihow.model

# %%
cd fastText
# Out:
# /content/drive/My Drive/AI_Experiment/generate_slide/fastText

# %%
! pip3 install .
# Out:
# Processing /content/drive/My Drive/AI_Experiment/generate_slide/fastText
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp36-cp36m-linux_x86_64.whl size=3019898 sha256=8f5a74efc4d7d078d14325749aabc63150b614c3e40ed60b9f9391daff8ceed6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o3__zc11/wheels/8e/2c/f1/10775d56db553501fc16da1926e851dddc04cf7f79bbc46760
# Successfully built fasttext
# ...

# %%
cd ../
# Out:
# /content/drive/My Drive/AI_Experiment/generate_slide

# %%
! pip3 install Janome==0.3.1.0
# Out:
# ...
#      |████████████████████████████████| 15.2MB 331kB/s
# ...
#   Created wheel for Janome: filename=Janome-0.3.1-cp36-none-any.whl size=15488375 sha256=fc5e1c6a31cdc4b701ca26eb4963a72531e96d4b4a1641fbcc6b4e11a28468fd
#   Stored in directory: /root/.cache/pip/wheels/40/cb/6d/79bf6e610eec5212d5ad018c1490601a0380051a5e05aaaec6
# Successfully built Janome
# ...

# %%
! python3 prediction.py script.txt out.md wikihow colab
# Out:
# 自宅 の ある JR 我孫子 駅 で は 、 保 線区 から 線路 を またい で ちょい ちょい と ホーム に 上がれ ば ６ 分 は 早い 電車 に 乗れる 自動 改札 機 の 導入 に JR 東日本 は 積極 的 で ある 改札 口 を 通る ため だけ に 、 毎日 非常 な 遠回り を し て いる しか し 、 しゃべら ない こと に は 何 に も 生まれ ない 沈黙 は 禁 なり 相手 に 面 と 向っ て 自分 の 意見 を 述べ 、 相手 の 意見 を 聞い て 議論 しよ う
# 1 category = 学び・コミュニケーション (probability = 0.8113850355148315) generating...
# 2 category = 旅行 (probability = 0.11600791662931442) generating...
# 3 category = 人間関係 (probability = 0.054727740585803986) generating...
# finished
