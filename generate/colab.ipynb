# %%
from google.colab import drive
drive.mount('/content/drive',  force_remount=True)

# %%
cd /content/drive/My Drive/AI_Experiment/generate_slide

# %%
# みなさんの置いたところにcdしてください

# %%
ls

# %%
git clone https://github.com/facebookresearch/fastText.git

# %%
cd fastText

# %%
! pip3 install .

# %%
cd ../

# %%
! pip3 install Janome==0.3.1.0

# %%
! python3 prediction.py sample.txt sample.md wikihow colab
