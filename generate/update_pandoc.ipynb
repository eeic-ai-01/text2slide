# %% [markdown]
# 👇のコマンド、colabに標準インストール（！）のpandocがpptx出力に対応していないことへの対応です
#
# 40分くらいかかるらしい（震え

# %%
# !curl -sSL https://get.haskellstack.org/ | sh
# !stack install pandoc --verbose >& pandoc.log
# !/root/.local/bin/pandoc --version
